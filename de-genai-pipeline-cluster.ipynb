# %%
spark.sql("""
SELECT COUNT(*)
FROM genai_support_pipeline.bronze_support_tickets
""").show()

spark.sql("""
DESCRIBE genai_support_pipeline.bronze_support_tickets
""").show(truncate=False)
# Out:
# +--------+
# |COUNT(*)|
# +--------+
# |   18762|
# +--------+
#
# +----------------------------+---------+-------+
# |col_name                    |data_type|comment|
# +----------------------------+---------+-------+
# |ticket_id                   |bigint   |NULL   |
# |customer_name               |string   |NULL   |
# |customer_email              |string   |NULL   |
# |customer_age                |bigint   |NULL   |
# |customer_gender             |string   |NULL   |
# |product_purchased           |string   |NULL   |
# |date_of_purchase            |date     |NULL   |
# |ticket_type                 |string   |NULL   |
# |ticket_subject              |string   |NULL   |
# |ticket_description          |string   |NULL   |
# |ticket_status               |string   |NULL   |
# |ticket_priority             |string   |NULL   |
# |ticket_channel              |string   |NULL   |
# |first_response_time         |timestamp|NULL   |
# |time_to_resolution          |timestamp|NULL   |
# ...
